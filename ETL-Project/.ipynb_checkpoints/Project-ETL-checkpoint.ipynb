# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "movie.csv"
movie_df = pd.read_csv(csv_file)
movie_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
csv_file = "oscars.csv"
oscars_df = pd.read_csv(csv_file)
oscars_df
# Out:
#       Year  Ceremony                          Award  Winner  \
# 0     1928         1                          Actor     NaN
# 1     1928         1                          Actor     1.0
# 2     1928         1                        Actress     NaN
# 3     1928         1                        Actress     1.0
# 4     1928         1                        Actress     NaN
# 5     1928         1                  Art Direction     NaN
# 6     1928         1                  Art Direction     1.0
# 7     1928         1                  Art Direction     NaN
# 8     1928         1                 Cinematography     NaN
# 9     1928         1                 Cinematography     1.0
# 10    1928         1                 Cinematography     1.0
# 11    1928         1     Directing (Comedy Picture)     1.0
# 12    1928         1     Directing (Comedy Picture)     NaN
# 13    1928         1   Directing (Dramatic Picture)     1.0
# 14    1928         1   Directing (Dramatic Picture)     NaN
# ...

# %%
oscars_df_drop=oscars_df.drop(columns=['Ceremony','Name'])

# %%
oscars_new_df=oscars_df_drop.loc[oscars_df_drop['Year'] >= 1995]

# %%
oscars_new_df
# Out:
#       Year                          Award  Winner  \
# 7228  1995        Actor in a Leading Role     1.0
# 7229  1995        Actor in a Leading Role     NaN
# 7230  1995        Actor in a Leading Role     NaN
# 7231  1995        Actor in a Leading Role     NaN
# 7232  1995        Actor in a Leading Role     NaN
# 7233  1995     Actor in a Supporting Role     NaN
# 7234  1995     Actor in a Supporting Role     NaN
# 7235  1995     Actor in a Supporting Role     NaN
# 7236  1995     Actor in a Supporting Role     NaN
# 7237  1995     Actor in a Supporting Role     1.0
# 7238  1995      Actress in a Leading Role     1.0
# 7239  1995      Actress in a Leading Role     NaN
# 7240  1995      Actress in a Leading Role     NaN
# 7241  1995      Actress in a Leading Role     NaN
# 7242  1995      Actress in a Leading Role     NaN
# 7243  1995   Actress in a Supporting Role     NaN
# 7244  1995   Actress in a Supporting Role     NaN
# 7245  1995   Actress in a Supporting Role     1.0
# ...

# %%
oscars=oscars_new_df.dropna()

# %%
oscars_winners=oscars.drop(columns=['Winner'])

# %%
oscars_winners
# Out:
#       Year                                              Award  \
# 7228  1995                            Actor in a Leading Role
# 7237  1995                         Actor in a Supporting Role
# 7238  1995                          Actress in a Leading Role
# 7245  1995                       Actress in a Supporting Role
# 7251  1995                                      Art Direction
# 7254  1995                                     Cinematography
# 7259  1995                                     Costume Design
# 7264  1995                                          Directing
# 7268  1995                              Documentary (Feature)
# 7276  1995                        Documentary (Short Subject)
# 7278  1995                                       Film Editing
# 7284  1995                              Foreign Language Film
# 7288  1995                                             Makeup
# 7294  1995                    Music (Original Dramatic Score)
# ...

# %%
database = ""
server = "localhost:5432"
engine = create_engine('postgres://postgres:password@localhost:5432/database')
conn = engine.connect()

# %%
oscars_winners.to_sql(name='oscars', conn=engine, if_exists='append', index=True)
